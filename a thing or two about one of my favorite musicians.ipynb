# %%
# Import the relevant modules
import requests
import json

# %%
# The documentation for this particular API can be found here:
# https://affiliate.itunes.apple.com/resources/documentation/itunes-store-web-service-search-api/

# %%
# define base URL
base_site = "https://itunes.apple.com/search"

# %%
# Make a request
r = requests.get(base_site, params = {"term": "cookin on 3 burners", "country": "us", "limit": 200})
r.status_code

# %%
# Store the response
info = r.json()

# %% [markdown]
# ### Inspect the structure of the response

# %%
print(json.dumps(info, indent=4))

# %%
# Inspect only the details of the first result
print(json.dumps(info['results'][0], indent=4))

# %% [markdown]
# ### Locate the name and release date of a song

# %%
info['results'][0]['trackName']

# %%
info['results'][0]['releaseDate']

# %% [markdown]
# ### Print the name of all songs

# %%
# Loop through all results and get the track names
for result in info['results']:
    print(result['trackName'])

# %% [markdown]
# ### Print out the release date of all songs

# %%
for result in info['results']:
    print(result['releaseDate'])

# %%
# Display as a table
import pandas as pd

songs_df = pd.DataFrame(info["results"])
songs_df
# Out:
#     wrapperType  kind    artistId  collectionId     trackId  \
# 0         track  song   885054140  1.440895e+09  1440894921
# 1         track  song   885054140  1.440513e+09  1440513768
# 2         track  song   885054140  1.443855e+09  1443854734
# 3         track  song   885054140  1.445037e+09  1445037234
# 4         track  song   885054140  1.445037e+09  1445037235
# ..          ...   ...         ...           ...         ...
# 126       track  song   200912093  1.254104e+09  1254103667
# 127       track  song   200912093  1.220115e+09  1220116259
# 128       track  song  1452692902  1.452693e+09  1452692896
# 129       track  song   885054140  1.445037e+09  1445037239
# 130       track  song  1168348602  1.168349e+09  1168348627
#
#                                          artistName  \
# 0                      Kungs & Cookin' On 3 Burners
# 1                      Kungs & Cookin' On 3 Burners
# 2                      Kungs & Cookin' On 3 Burners
# 3                      Kungs & Cookin' On 3 Burners
# 4                      Kungs & Cookin' On 3 Burners
# ..                                              ...
# 126                            Cookin' On 3 Burners
# 127                            Cookin' On 3 Burners
# 128  Cookin' On 3 Burners feat. Daniel Merriweather
# 129                                           Kungs
# 130                                    KoldKuttKeys
#
#                              collectionName  \
# 0                                    Layers
# 1    NOW That's What I Call Music!, Vol. 60
# 2                        This Is Future Pop
# 3                            This Girl - EP
# 4                            This Girl - EP
# ..                                      ...
# 126          Brunswick St. Breakdown (Live)
# 127                                     Vs.
# 128                               Blind Bet
# 129                          This Girl - EP
# 130                          We Dab Daddies
#
#                                       trackName  \
# 0                                     This Girl
# 1    This Girl (Kungs Vs. Cookin' On 3 Burners)
# 2    This Girl (Kungs Vs. Cookin' On 3 Burners)
# 3     This Girl (Kungs vs Cookin' On 3 Burners)
# 4     This Girl (Kungs vs Cookin' On 3 Burners)
# ..                                          ...
# 126                              Redback (Live)
# 127   Losin' Streak (feat. Daniel Merriweather)
# 128                               Losin' Streak
# 129   This Girl (Kungs vs Cookin' On 3 Burners)
# 130                 Kungs & Cookin On 3 Burners
#
#                      collectionCensoredName  \
# 0                                    Layers
# 1    NOW That's What I Call Music!, Vol. 60
# 2                        This Is Future Pop
# 3                            This Girl - EP
# 4                            This Girl - EP
# ..                                      ...
# 126          Brunswick St. Breakdown (Live)
# 127                                     Vs.
# 128                               Blind Bet
# 129                          This Girl - EP
# 130                          We Dab Daddies
#
#                                      trackCensoredName  ... trackCount  \
# 0                                            This Girl  ...       12.0
# 1           This Girl (Kungs Vs. Cookin' On 3 Burners)  ...       22.0
# 2           This Girl (Kungs Vs. Cookin' On 3 Burners)  ...       16.0
# 3    This Girl (Kungs vs Cookin' On 3 Burners) [Ext...  ...        4.0
# 4    This Girl (Kungs vs Cookin' On 3 Burners) [Fab...  ...        4.0
# ..                                                 ...  ...        ...
# 126                                     Redback (Live)  ...        9.0
# 127          Losin' Streak (feat. Daniel Merriweather)  ...       10.0
# 128                                      Losin' Streak  ...       11.0
# 129          This Girl (Kungs vs Cookin' On 3 Burners)  ...        4.0
# 130                        Kungs & Cookin On 3 Burners  ...       28.0
#
#     trackNumber trackTimeMillis country currency primaryGenreName  \
# 0           2.0          195541     USA      USD            Dance
# 1          10.0          193773     USA      USD       Electronic
# 2           1.0          195533     USA      USD       Electronic
# 3           1.0          242736     USA      USD       Electronic
# 4           2.0          259672     USA      USD       Electronic
# ..          ...             ...     ...      ...              ...
# 126         1.0          264019     USA      USD         R&B/Soul
# 127         7.0          224832     USA      USD       Electronic
# 128         4.0          224832     USA      USD         R&B/Soul
# 129         4.0          216312     USA      USD       Electronic
# 130        23.0          380369     USA      USD            Dance
#
#     isStreamable collectionArtistId  \
# 0           True                NaN
# 1           True            36270.0
# 2           True            36270.0
# 3           True                NaN
# 4           True                NaN
# ..           ...                ...
# 126         True                NaN
# 127         True                NaN
# 128         True        200912093.0
# 129         True                NaN
# 130         True                NaN
#
#                                collectionArtistViewUrl  contentAdvisoryRating
# 0                                                  NaN                    NaN
# 1                                                  NaN                    NaN
# 2                                                  NaN                    NaN
# 3                                                  NaN                    NaN
# 4                                                  NaN                    NaN
# ..                                                 ...                    ...
# 126                                                NaN                    NaN
# 127                                                NaN                    NaN
# 128  https://music.apple.com/us/artist/cookin-on-3-...                    NaN
# 129                                                NaN                    NaN
# 130                                                NaN               Explicit
#
# [131 rows x 35 columns]
